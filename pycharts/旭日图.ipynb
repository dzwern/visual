# %%
# 导入模块

from pyecharts.charts import Sunburst
from pyecharts import options as opts

# %%
# 导入数据,数据展示位一级接着一级，分级进行展示
data = [
    opts.SunburstItem(
        name="Grandpa",
        children=[
            opts.SunburstItem(
                name="Uncle Leo",
                value=15,
                children=[
                    opts.SunburstItem(name="Cousin Jack", value=2),
                    opts.SunburstItem(
                        name="Cousin Mary",
                        value=5,
                        children=[opts.SunburstItem(name="Jackson", value=2)],
                    ),
                    opts.SunburstItem(name="Cousin Ben", value=4),
                ],
            ),
            opts.SunburstItem(
                name="Father",
                value=10,
                children=[
                    opts.SunburstItem(name="Me", value=5),
                    opts.SunburstItem(name="Brother Peter", value=1),
                ],
            ),
        ],
    ),
    opts.SunburstItem(
        name="Nancy",
        children=[
            opts.SunburstItem(
                name="Uncle Nike",
                children=[
                    opts.SunburstItem(name="Cousin Betty", value=1),
                    opts.SunburstItem(name="Cousin Jenny", value=2),
                ],
            )
        ],
    ),
]

data
# Out:
# [<pyecharts.options.charts_options.SunburstItem at 0x18d4f3af688>,
#  <pyecharts.options.charts_options.SunburstItem at 0x18d4f3afc48>]

# %%
sunburst=(
    Sunburst(init_opts=opts.InitOpts(width='1000px',height='600px'))
    .add(series_name='',data_pair=data,radius=[0,'90%'])
    .set_global_opts(title_opts=opts.TitleOpts(title='旭日图基础展示'))
    .set_series_opts(label_opts=opts.LabelOpts(formatter='{b}'))
)

sunburst.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2459ca6c1c39473a8aa7d10995971e22" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2459ca6c1c39473a8aa7d10995971e22 = echarts.init(
#                     document.getElementById('2459ca6c1c39473a8aa7d10995971e22'), 'white', {renderer: 'canvas'});
#                 var option_2459ca6c1c39473a8aa7d10995971e22 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "data": [
#                 {
#                     "name": "Grandpa",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "value": 15,
#                             "name": "Uncle Leo",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jack",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 5,
#                                     "name": "Cousin Mary",
#                                     "target": "blank",
#                                     "children": [
#                                         {
#                                             "value": 2,
#                                             "name": "Jackson",
#                                             "target": "blank"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "value": 4,
#                                     "name": "Cousin Ben",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 10,
#                             "name": "Father",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 5,
#                                     "name": "Me",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 1,
#                                     "name": "Brother Peter",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Nancy",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "Uncle Nike",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 1,
#                                     "name": "Cousin Betty",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jenny",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 0,
#                 "90%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u65ed\u65e5\u56fe\u57fa\u7840\u5c55\u793a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2459ca6c1c39473a8aa7d10995971e22.setOption(option_2459ca6c1c39473a8aa7d10995971e22);
#         });
#     </script>

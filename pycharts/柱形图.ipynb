# %%
# 配置项
from pyecharts import options as opts
# 柱形图
from pyecharts.charts import Bar
# 数据集
from pyecharts.faker import Faker
# 主题配置
from pyecharts.globals import ThemeType

# %%
# 基础图形

c=(
    Bar()
#     Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    # 等价于 Bar(init_opts=opts.InitOpts(theme=ThemeType.WHITE))
    # x轴选择的数据
    .add_xaxis(Faker.choose())
    # y轴选择的数据
    .add_yaxis('商家A',Faker.values())
    # 配置全局项
    .set_global_opts(title_opts=opts.TitleOpts(title='柱形图示例',subtitle='副标题'))
)
# 输出在网页面上
c.render_notebook()
# 输出在本地中
# c.render('./bar_base.html')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="be07f66f7e59462f87cb6d1d33cfaf89" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_be07f66f7e59462f87cb6d1d33cfaf89 = echarts.init(
#                     document.getElementById('be07f66f7e59462f87cb6d1d33cfaf89'), 'light', {renderer: 'canvas'});
#                 var option_be07f66f7e59462f87cb6d1d33cfaf89 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 46,
# ...

# %%
# 基础图形的绘制
# add_xaxis()中可以输入列表
# set_series_opts  表示系列配置项
# set_global_opts  表示全局配置项


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), stack="stack1")
    .add_yaxis("商家B", Faker.values(), stack="stack1")
    # 标签配置项（is_show是否显示）
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    # 标题配置项
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（全部）")) 
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="31c4b590f9384ad08622cb599370b810" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_31c4b590f9384ad08622cb599370b810 = echarts.init(
#                     document.getElementById('31c4b590f9384ad08622cb599370b810'), 'white', {renderer: 'canvas'});
#                 var option_31c4b590f9384ad08622cb599370b810 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# Faker.choose()
Faker.values()
# Out:
# [97, 48, 68, 147, 21, 28, 68]

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
# 插入js代码
from pyecharts.commons.utils import JsCode
# 全局主题配置
from pyecharts.globals import ThemeType

# 数据可以是列表中加dict类型数据

list2 = [
    {"value": 12, "percent": 12 / (12 + 3)},
    {"value": 23, "percent": 23 / (23 + 21)},
    {"value": 33, "percent": 33 / (33 + 5)},
    {"value": 3, "percent": 3 / (3 + 52)},
    {"value": 33, "percent": 33 / (33 + 43)},
]

list3 = [
    {"value": 3, "percent": 3 / (12 + 3)},
    {"value": 21, "percent": 21 / (23 + 21)},
    {"value": 5, "percent": 5 / (33 + 5)},
    {"value": 52, "percent": 52 / (3 + 52)},
    {"value": 43, "percent": 43 / (33 + 43)},
]

d = (
    # 主题配置
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis([1, 2, 3, 4, 5])
    .add_yaxis("product1", list2, stack="stack1", category_gap="50%")
    .add_yaxis("product2", list3, stack="stack1", category_gap="50%")
    # 系列值配置，标签配置
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
    
)

d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c56a30663d6447978ea31e4857bb7a4e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c56a30663d6447978ea31e4857bb7a4e = echarts.init(
#                     document.getElementById('c56a30663d6447978ea31e4857bb7a4e'), 'light', {renderer: 'canvas'});
#                 var option_c56a30663d6447978ea31e4857bb7a4e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "product1",
#             "data": [
#                 {
# ...

# %%
print(type(list2[0]))
# Out:
# <class 'dict'>

# %%
# 浮层柱形图的绘制

# 导入模块
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
# 数据集
# 时间轴
x_data = [f"11月{str(i)}日" for i in range(1, 12)]
# y的总值
y_total = [0, 900, 1245, 1530, 1376, 1376, 1511, 1689, 1856, 1495, 1292]
y_in = [900, 345, 393, "-", "-", 135, 178, 286, "-", "-", "-"]
y_out = ["-", "-", "-", 108, 154, "-", "-", "-", 119, 361, 203]

# %%
# 图形展示
e=(
    Bar()
    # 数据x
    .add_xaxis(xaxis_data=x_data)
    # y值
    .add_yaxis(series_name='',
               yaxis_data=y_total,
              stack='总量',
               # 图形颜色的配置
              itemstyle_opts=opts.ItemStyleOpts(color='rgba(0,0,0,0)'))
    # 在原有的基础上绘制新的图形
    .add_yaxis(series_name='收入',yaxis_data=y_in,stack='总量')
    .add_yaxis(series_name='支出',yaxis_data=y_out,stack='总量')
    # 全局配置项，坐标轴的类型，为数值型数据
    .set_global_opts(yaxis_opts=opts.AxisOpts(type_='value')))

e.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="738b3b1640f147fdb9c89f1f4f927494" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_738b3b1640f147fdb9c89f1f4f927494 = echarts.init(
#                     document.getElementById('738b3b1640f147fdb9c89f1f4f927494'), 'white', {renderer: 'canvas'});
#                 var option_738b3b1640f147fdb9c89f1f4f927494 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 带有标记注释的柱形图

# 导入模块
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

# %%
# 图形展示
f=(Bar()
  .add_xaxis(Faker.choose())
  .add_yaxis('商家A',Faker.values())
  .add_yaxis('商家B',Faker.values())
    # 全局配置项
  .set_global_opts(title_opts=opts.TitleOpts(title='指定类型'))
  .set_series_opts(
      # 标签配置项
      label_opts=opts.LabelOpts(is_show=False),
      # 标记点配置项，图形标记的类型circle，rect等等，也可以使用链接图片
      markpoint_opts=opts.MarkPointOpts(
          data=[
              opts.MarkPointItem(type_='max',name='最大值'),
              opts.MarkPointItem(type_='min',name='最小值'),
              opts.MarkPointItem(type_='average',name='平均值'),
          ]),))

   
f.render_notebook()


# 自定义标点

'''
在add_yaxis中加入配置项，markpoint_opts=opts.MarkPoints(
data=[opts.MarkPointItem(name='自定义标记点',coord=[x[2],y[2],value=y[2]])])
'''
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce59c4edd8d941578fb7e58e9b3cdf49" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce59c4edd8d941578fb7e58e9b3cdf49 = echarts.init(
#                     document.getElementById('ce59c4edd8d941578fb7e58e9b3cdf49'), 'white', {renderer: 'canvas'});
#                 var option_ce59c4edd8d941578fb7e58e9b3cdf49 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 缩放图
# 导入模块


from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.faker import Faker

# %%
g=(
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis('商家A',Faker.days_values,color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title='缩放图'),
        # 缩放图配置，类型有slider，inside
        datazoom_opts=[opts.DataZoomOpts(),opts.DataZoomOpts(type_='slider')])
)

g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2848a30535ed4df1a26aa942d785669d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2848a30535ed4df1a26aa942d785669d = echarts.init(
#                     document.getElementById('2848a30535ed4df1a26aa942d785669d'), 'white', {renderer: 'canvas'});
#                 var option_2848a30535ed4df1a26aa942d785669d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#749f83",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

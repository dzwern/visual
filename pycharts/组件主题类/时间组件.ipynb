# %%
# 柱形图时间组件

from pyecharts import options as opts
from pyecharts.charts import Bar,Timeline
from pyecharts.faker import Faker

# %%
# 导入数据
x=Faker.choose()
t1=Timeline()

# %%
for i in range(2015,2020):
    bar=(
        Bar()
        .add_xaxis(x)
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('某商店{}年营业额'.format(i)))
    )
    t1.add(bar,"{}年".format(i))
    
t1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7c53c4c60d96423dad4b9243262b5939" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7c53c4c60d96423dad4b9243262b5939 = echarts.init(
#                     document.getElementById('7c53c4c60d96423dad4b9243262b5939'), 'white', {renderer: 'canvas'});
#                 var option_7c53c4c60d96423dad4b9243262b5939 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6A",
#                 "data": [
#                     132,
#                     32,
#                     46,
#                     110,
#                     117,
#                     106,
#                     38
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6B",
#                 "data": [
#                     119,
#                     64,
#                     57,
#                     62,
#                     55,
#                     87,
#                     149
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A",
#                         "\u5546\u5bb6B"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true,
#                         "\u5546\u5bb6B": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "\u5546\u5bb6A",
#                     "data": [
#                         93,
#                         49,
#                         41,
#                         71,
#                         104,
#                         76,
#                         57
#                     ],
#                     "barCategoryGap": "20%",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "\u5546\u5bb6B",
#                     "data": [
#                         110,
#                         109,
#                         38,
#                         143,
#                         83,
#                         148,
#                         149
#                     ],
#                     "barCategoryGap": "20%",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "\u8349\u8393",
#                         "\u8292\u679c",
#                         "\u8461\u8404",
#                         "\u96ea\u68a8",
#                         "\u897f\u74dc",
#                         "\u67e0\u6aac",
#                         "\u8f66\u5398\u5b50"
#                     ]
#                 }
#             ],
#             "yAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5e972015\u5e74\u8425\u4e1a\u989d",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },

# %%
# 地图时间轴
from pyecharts.charts import Map,Timeline

t1=Timeline()
for i in range(2015,2020):
    map=(
        Map()
        .add('商家A',[list(z) for z in zip(Faker.provinces,Faker.values())],'china')
        .set_global_opts(
            title_opts=opts.TitleOpts(title='map-{}年数据'.format(i)),
            visualmap_opts=opts.VisualMapOpts(max_=200)
        )
    )
    t1.add(map,'{}年'.format(i))
t1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ff18958b8cce489fbf7137a18457d191" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ff18958b8cce489fbf7137a18457d191 = echarts.init(
#                     document.getElementById('ff18958b8cce489fbf7137a18457d191'), 'white', {renderer: 'canvas'});
#                 var option_ff18958b8cce489fbf7137a18457d191 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "name": "\u5546\u5bb6A",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "mapType": "china",
#                 "data": [
#                     {
#                         "name": "\u5e7f\u4e1c",
#                         "value": 91
#                     },
#                     {
#                         "name": "\u5317\u4eac",
#                         "value": 143
#                     },
#                     {
#                         "name": "\u4e0a\u6d77",
#                         "value": 108
#                     },
#                     {
#                         "name": "\u6c5f\u897f",
#                         "value": 53
#                     },
#                     {
#                         "name": "\u6e56\u5357",
#                         "value": 40
#                     },
#                     {
#                         "name": "\u6d59\u6c5f",
#                         "value": 30
#                     },
#                     {
#                         "name": "\u6c5f\u82cf",
#                         "value": 38
#                     }
#                 ],
#                 "roam": true,
#                 "zoom": 1,
#                 "showLegendSymbol": true,
#                 "emphasis": {}
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "visualMap": {
#             "show": true,
#             "type": "continuous",
#             "min": 0,
#             "max": 200,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "inverse": false,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "showLabel": true,
#             "itemWidth": 20,
#             "itemHeight": 140,
#             "borderWidth": 0
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "map",
#                     "name": "\u5546\u5bb6A",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     },
#                     "mapType": "china",
#                     "data": [
#                         {
#                             "name": "\u5e7f\u4e1c",
#                             "value": 90
#                         },
#                         {
#                             "name": "\u5317\u4eac",
#                             "value": 120
#                         },
#                         {
#                             "name": "\u4e0a\u6d77",
#                             "value": 49
#                         },
#                         {
#                             "name": "\u6c5f\u897f",
#                             "value": 110
#                         },
#                         {
#                             "name": "\u6e56\u5357",
#                             "value": 113
#                         },
#                         {
#                             "name": "\u6d59\u6c5f",
#                             "value": 100
#                         },
#                         {
#                             "name": "\u6c5f\u82cf",
#                             "value": 106
#                         }
#                     ],
#                     "roam": true,
#                     "zoom": 1,
#                     "showLegendSymbol": true,
#                     "emphasis": {}
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "map-2015\u5e74\u6570\u636e",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "visualMap": {
#                 "show": true,
#                 "type": "continuous",
#                 "min": 0,
#                 "max": 200,
#                 "inRange": {
#                     "color": [
#                         "#50a3ba",
#                         "#eac763",
#                         "#d94e5d"
#                     ]
#                 },
#                 "calculable": true,
#                 "inverse": false,
#                 "splitNumber": 5,
#                 "orient": "vertical",
#                 "showLabel": true,
#                 "itemWidth": 20,
#                 "itemHeight": 140,
#                 "borderWidth": 0
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "map",
#                     "name": "\u5546\u5bb6A",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     },
#                     "mapType": "china",
#                     "data": [
#                         {
#                             "name": "\u5e7f\u4e1c",
#                             "value"

# %%
# 饼图时间轴
from pyecharts.charts import Pie,Timeline

attr = Faker.choose()
tl = Timeline()
for i in range(2015, 2020):
    pie = (
        Pie()
        .add(
            "商家A",
            [list(z) for z in zip(attr, Faker.values())],
            rosetype="radius",
            radius=["30%", "55%"],
        )
        .set_global_opts(title_opts=opts.TitleOpts("某商店{}年营业额".format(i)))
    )
    tl.add(pie, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6471bed6fc204baaa35a47e2f851bec1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6471bed6fc204baaa35a47e2f851bec1 = echarts.init(
#                     document.getElementById('6471bed6fc204baaa35a47e2f851bec1'), 'white', {renderer: 'canvas'});
#                 var option_6471bed6fc204baaa35a47e2f851bec1 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "\u5546\u5bb6A",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\u5c0f\u7c73",
#                         "value": 124
#                     },
#                     {
#                         "name": "\u4e09\u661f",
#                         "value": 52
#                     },
#                     {
#                         "name": "\u534e\u4e3a",
#                         "value": 95
#                     },
#                     {
#                         "name": "\u82f9\u679c",
#                         "value": 135
#                     },
#                     {
#                         "name": "\u9b45\u65cf",
#                         "value": 147
#                     },
#                     {
#                         "name": "VIVO",
#                         "value": 88
#                     },
#                     {
#                         "name": "OPPO",
#                         "value": 48
#                     }
#                 ],
#                 "radius": [
#                     "30%",
#                     "55%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "roseType": "radius",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5c0f\u7c73",
#                         "\u4e09\u661f",
#                         "\u534e\u4e3a",
#                         "\u82f9\u679c",
#                         "\u9b45\u65cf",
#                         "VIVO",
#                         "OPPO"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "\u5546\u5bb6A",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\u5c0f\u7c73",
#                             "value": 123
#                         },
#                         {
#                             "name": "\u4e09\u661f",
#                             "value": 81
#                         },
#                         {
#                             "name": "\u534e\u4e3a",
#                             "value": 131
#                         },
#                         {
#                             "name": "\u82f9\u679c",
#                             "value": 113
#                         },
#                         {
#                             "name": "\u9b45\u65cf",
#                             "value": 24
#                         },
#                         {
#                             "name": "VIVO",
#                             "value": 117
#                         },
#                         {
#                             "name": "OPPO",
#                             "value": 78
#                         }
#                     ],
#                     "radius": [
#                         "30%",
#                         "55%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "roseType": "radius",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5e972015\u5e74\u8425\u4e1a\u989d",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5c0f\u7c73",
#                         "\u4e09\u661f",
#                         "\u534e\u4e3a",
#                         "\u82f9\u679c",
#                         "\u9b45\u65cf",
#                         "VIVO",
#                         "OPPO"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "\u5546\u5bb6A",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\u5c0f\u7c73",
#                             "value": 67
#                         },
#                         {
#                             "name": "\u4e09\u661f",
#                             "value": 65
#                         },
#                         {
#                             "name": "\u534e\u4e3a",
#                             "value": 59
#                         },
#                         {
#                             "name": "\u82f9\u679c",
#                             "value": 102
#                         },
#                         {
#                             "name": "\u9b45\u65cf",
#                             "value": 30
#                         },
#                         {
#                             "name": "VIVO",
#                             "value": 55
#                         },
#                         {
#                             "name": "OPPO",
#                             "value": 52
#                         }
#                     ],

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar,Page
from pyecharts.faker import Collector,Faker
from pyecharts.globals import ThemeType

# %%
C=Collector()

# %%
@C.funcs
def theme_default():
    c=(
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c



@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.INFOGRAPHIC))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c



@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.MACARONS))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c



@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMANTIC))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.SHINE))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c



@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.WALDEN))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


@C.funcs
def theme_default():
    c=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.WONDERLAND))
        .add_xaxis(Faker.choose())
        .add_yaxis('商家A',Faker.values())
        .add_yaxis('商家B',Faker.values())
        .add_yaxis('商家C',Faker.values())
        .add_yaxis('商家D',Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts('柱形图展示'))
    )
    return c


Page().add(*[fn() for fn, _ in C.charts]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk', 'essos':'https://assets.pyecharts.org/assets/themes/essos', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion', 'roma':'https://assets.pyecharts.org/assets/themes/roma', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic', 'shine':'https://assets.pyecharts.org/assets/themes/shine', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage', 'walden':'https://assets.pyecharts.org/assets/themes/walden', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros', 'wonderland':'https://assets.pyecharts.org/assets/themes/wonderland'
#         }
#     });
# </script>
#
#         <div id="969a6202d0d848b2ba80a4ab4d80fceb" style="width:900px; height:500px;"></div>
#         <div id="c4c36a0f76784d279640a19f953c4287" style="width:900px; height:500px;"></div>
#         <div id="172b1823da4d405a91cb7212e1f7f070" style="width:900px; height:500px;"></div>
#         <div id="f9a2df3019204aea8fe34feee9364c92" style="width:900px; height:500px;"></div>
#         <div id="d06da50abf214165b1bf47f07981747a" style="width:900px; height:500px;"></div>
#         <div id="575ec7cc10ed4f2aa0b83c1ef91605af" style="width:900px; height:500px;"></div>
#         <div id="bcf954be70154355afbed75d101e8440" style="width:900px; height:500px;"></div>
#         <div id="b2ee25395fa14584819f68ac30428bf1" style="width:900px; height:500px;"></div>
#         <div id="d08a32f9bc8145dc80633f67b4237a79" style="width:900px; height:500px;"></div>
#         <div id="9a4fdd33567c47f4a97a0e78b1def75b" style="width:900px; height:500px;"></div>
#         <div id="fc1b400717ee483ebf9e8454e38760da" style="width:900px; height:500px;"></div>
#         <div id="263639470fb342458ac1498bf2ba7aa7" style="width:900px; height:500px;"></div>
#         <div id="d17dab49c202442bb57a562134f4a149" style="width:900px; height:500px;"></div>
#         <div id="dcd4e9bdb92c4acfb9846eff2f61c464" style="width:900px; height:500px;"></div>
#         <div id="628d981de32644b49864f20a77413918" style="width:900px; height:500px;"></div>
#         <div id="9f088d98229446658b4f1b279814f102" style="width:900px; height:500px;"></div>
#         <div id="13512d4c63cb4a1db4ea89fdb2988611" style="width:900px; height:500px;"></div>
#         <div id="747581445f704c929a21af609bb50fe9" style="width:900px; height:500px;"></div>
#         <div id="fcc30346ea624f2a91a10af7a2d4c411" style="width:900px; height:500px;"></div>
#         <div id="5e1171c121ea4d389d2c45d2cb7a06ee" style="width:900px; height:500px;"></div>
#         <div id="bf1edcca806c4574aa01d78f4ffe443b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk', 'essos', 'infographic', 'macarons', 'purple-passion', 'roma', 'romantic', 'shine', 'vintage', 'walden', 'westeros', 'wonderland'], function(echarts) {
#                 var chart_969a6202d0d848b2ba80a4ab4d80fceb = echarts.init(
#                     document.getElementById('969a6202d0d848b2ba80a4ab4d80fceb'), 'white', {renderer: 'canvas'});
#                 var option_969a6202d0d848b2ba80a4ab4d80fceb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 61,
#                 89,
#                 139,
#                 129,
#                 103,
#                 57,
#                 36
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 110,
#                 59,
#                 91,
#                 87,
#                 87,
#                 66,
#                 20
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 31,
#                 141,
#                 54,
#                 144,
#                 72,
#                 146,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 41,
#                 96,
#                 21,
#                 69,
#                 85,
#                 26,
#                 141
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,

# %%
from pyecharts import options as opts
# 地图绘制函数
from pyecharts.charts import Geo
# 数据集
from pyecharts.faker import Faker
from pyecharts.globals import ChartType
# 在线导入数据
from pyecharts.datasets import register_url

from pyecharts.globals import ChartType, SymbolType
from pyecharts.charts import Map

# %%
Faker.provinces
# Out:
# ['广东', '北京', '上海', '江西', '湖南', '浙江', '江苏']

# %%
c = (
    Geo()
    # 地图类型
    .add_schema(maptype="china")
    
    .add("中国地图", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="859f194fc2764fa5a0ed6f694a55e9a1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_859f194fc2764fa5a0ed6f694a55e9a1 = echarts.init(
#                     document.getElementById('859f194fc2764fa5a0ed6f694a55e9a1'), 'white', {renderer: 'canvas'});
#                 var option_859f194fc2764fa5a0ed6f694a55e9a1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u4e2d\u56fd\u5730\u56fe",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         43
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         117
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         128
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         42
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         132
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         136
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e2d\u56fd\u5730\u56fe"
#             ],
#             "selected": {
#                 "\u4e2d\u56fd\u5730\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_859f194fc2764fa5a0ed6f694a55e9a1.setOption(option_859f194fc2764fa5a0ed6f694a55e9a1);
#         });
#     </script>

# %%
# 热力地图

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "中国地图",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        # 指定地图类型
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Geo-HeatMap"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="333ee128bfb548d1a25dbca23a04bd25" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_333ee128bfb548d1a25dbca23a04bd25 = echarts.init(
#                     document.getElementById('333ee128bfb548d1a25dbca23a04bd25'), 'white', {renderer: 'canvas'});
#                 var option_333ee128bfb548d1a25dbca23a04bd25 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u4e2d\u56fd\u5730\u56fe",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         48
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         106
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         35
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         52
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         123
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         54
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e2d\u56fd\u5730\u56fe"
#             ],
#             "selected": {
#                 "\u4e2d\u56fd\u5730\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-HeatMap",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_333ee128bfb548d1a25dbca23a04bd25.setOption(option_333ee128bfb548d1a25dbca23a04bd25);
#         });
#     </script>

# %%
try:
    register_url("https://echarts-maps.github.io/echarts-countries-js/")
except Exception:
    
    import ssl
    ssl._create_default_https_context = ssl._create_unverified_context
    register_url("https://echarts-maps.github.io/echarts-countries-js/")

geo = (
    Geo()
    .add_schema(maptype="瑞士")
    .set_global_opts(title_opts=opts.TitleOpts(title="瑞士"))
)

# %%
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '瑞士':'https://echarts-maps.github.io/echarts-countries-js//echarts-countries-js/Switzerland'
#         }
#     });
# </script>
#
#         <div id="de030197ed704544b03244ea98395a89" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '瑞士'], function(echarts) {
#                 var chart_de030197ed704544b03244ea98395a89 = echarts.init(
#                     document.getElementById('de030197ed704544b03244ea98395a89'), 'white', {renderer: 'canvas'});
#                 var option_de030197ed704544b03244ea98395a89 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u745e\u58eb",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "\u745e\u58eb",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_de030197ed704544b03244ea98395a89.setOption(option_de030197ed704544b03244ea98395a89);
#         });
#     </script>

# %%
d = (
    Geo()
    .add_schema(maptype="广东")
    .add(
        "广东地图",
        [list(z) for z in zip(Faker.guangdong_city, Faker.values())],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-广东地图")
    )
)

# %%
d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="240a5650323b446990fb1fdd5a1d74cc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_240a5650323b446990fb1fdd5a1d74cc = echarts.init(
#                     document.getElementById('240a5650323b446990fb1fdd5a1d74cc'), 'white', {renderer: 'canvas'});
#                 var option_240a5650323b446990fb1fdd5a1d74cc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u5e7f\u4e1c\u5730\u56fe",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": [
#                         116.68,
#                         23.35,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": [
#                         115.37,
#                         22.78,
#                         138
#                     ]
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": [
#                         116.37,
#                         23.55,
#                         107
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": [
#                         111.98,
#                         21.87,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": [
#                         112.47,
#                         23.05,
#                         69
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": [
#                         113.27,
#                         23.13,
#                         52
#                     ]
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": [
#                         114.42,
#                         23.12,
#                         140
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u4e1c\u5730\u56fe"
#             ],
#             "selected": {
#                 "\u5e7f\u4e1c\u5730\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u5e7f\u4e1c",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_240a5650323b446990fb1fdd5a1d74cc.setOption(option_240a5650323b446990fb1fdd5a1d74cc);
#         });
#     </script>

# %%
Faker.guangdong_city
# Out:
# ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市', '广州市', '惠州市']

# %%
e = (
    Geo()
    # 地图类型
    .add_schema(maptype="china")
    .add(
        "",
        # 设置目的地大小
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        # 线图
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            # 箭头
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines"))
)

# %%
e.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bcd43a4cfa29467bb91cd4641e1bb4e8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bcd43a4cfa29467bb91cd4641e1bb4e8 = echarts.init(
#                     document.getElementById('bcd43a4cfa29467bb91cd4641e1bb4e8'), 'white', {renderer: 'canvas'});
#                 var option_bcd43a4cfa29467bb91cd4641e1bb4e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 "geo"
#             ],
#             "selected": {
#                 "": true,
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-Lines",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_bcd43a4cfa29467bb91cd4641e1bb4e8.setOption(option_bcd43a4cfa29467bb91cd4641e1bb4e8);
#         });
#     </script>

# %%
f = (
    Geo()
    .add_schema(
        maptype="china",
        # 背景设置
        itemstyle_opts=opts.ItemStyleOpts(color="#323c48", border_color="#111"),
    )
    .add(
        "",
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines-background"))
)
f.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="f4209739fcf2434cb99931f784f7bec2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f4209739fcf2434cb99931f784f7bec2 = echarts.init(
#                     document.getElementById('f4209739fcf2434cb99931f784f7bec2'), 'white', {renderer: 'canvas'});
#                 var option_f4209739fcf2434cb99931f784f7bec2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 "geo"
#             ],
#             "selected": {
#                 "": true,
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-Lines-background",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "itemStyle": {
#             "color": "#323c48",
#             "borderColor": "#111"
#         },
#         "emphasis": {}
#     }
# };
#                 chart_f4209739fcf2434cb99931f784f7bec2.setOption(option_f4209739fcf2434cb99931f784f7bec2);
#         });
#     </script>

# %%
provinces = ["广东", "北京", "上海", "辽宁", "湖南", "四川", "西藏"]
guangdong_city = ["汕头市", "汕尾市", "揭阳市", "阳江市", "肇庆市", "广州市", "惠州市"]
country = ["China", "Canada", "Brazil", "Russia", "United States", "Africa", "Germany"]
value = [300, 100, 2000, 800, 10000, 400, 5000]

# %%
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bf3a5e082a0545eeacb2beaa726011cc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bf3a5e082a0545eeacb2beaa726011cc = echarts.init(
#                     document.getElementById('bf3a5e082a0545eeacb2beaa726011cc'), 'white', {renderer: 'canvas'});
#                 var option_bf3a5e082a0545eeacb2beaa726011cc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2000
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 800
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 10000
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 400
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 5000
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "map-\u57fa\u672c\u56fe\u5f62",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bf3a5e082a0545eeacb2beaa726011cc.setOption(option_bf3a5e082a0545eeacb2beaa726011cc);
#         });
#     </script>

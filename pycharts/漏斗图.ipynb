# %%
from pyecharts import options as opts
# 漏斗图设置
from pyecharts.charts import Funnel
# 自带数据集
from pyecharts.faker import Faker

# %%
# 使用zip压缩方式

c = (
    Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d190b55f9c0d4b11a426ef2021b9a3a4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d190b55f9c0d4b11a426ef2021b9a3a4 = echarts.init(
#                     document.getElementById('d190b55f9c0d4b11a426ef2021b9a3a4'), 'white', {renderer: 'canvas'});
#                 var option_d190b55f9c0d4b11a426ef2021b9a3a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 37
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u87d2\u86c7",
#                 "\u5154\u5b50",
#                 "\u6cb3\u9a6c",
#                 "\u5927\u8c61",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u8001\u864e"
#             ],
#             "selected": {
#                 "\u6cb3\u9a6c": true,
#                 "\u87d2\u86c7": true,
#                 "\u8001\u864e": true,
#                 "\u5927\u8c61": true,
#                 "\u5154\u5b50": true,
#                 "\u718a\u732b": true,
#                 "\u72ee\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d190b55f9c0d4b11a426ef2021b9a3a4.setOption(option_d190b55f9c0d4b11a426ef2021b9a3a4);
#         });
#     </script>

# %%
# 倒序

c = (
    Funnel()
    .add(
        "商品",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        # 倒序
        sort_="ascending",
        # 坐标标签放置的位置
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Sort（ascending）"))
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cf5e0314713c489b94d3dd373ed5d1d4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cf5e0314713c489b94d3dd373ed5d1d4 = echarts.init(
#                     document.getElementById('cf5e0314713c489b94d3dd373ed5d1d4'), 'white', {renderer: 'canvas'});
#                 var option_cf5e0314713c489b94d3dd373ed5d1d4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 137
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u87d2\u86c7",
#                 "\u5154\u5b50",
#                 "\u6cb3\u9a6c",
#                 "\u5927\u8c61",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u8001\u864e"
#             ],
#             "selected": {
#                 "\u6cb3\u9a6c": true,
#                 "\u87d2\u86c7": true,
#                 "\u8001\u864e": true,
#                 "\u5927\u8c61": true,
#                 "\u5154\u5b50": true,
#                 "\u718a\u732b": true,
#                 "\u72ee\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-Sort\uff08ascending\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cf5e0314713c489b94d3dd373ed5d1d4.setOption(option_cf5e0314713c489b94d3dd373ed5d1d4);
#         });
#     </script>
